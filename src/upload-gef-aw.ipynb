# %%
import requests
import json
import hashlib
import os
import re
from config import AW_KEY, AW_KEY_SAND

# %%
## ----------------------------------------------------------------------------
# PREP - URL AND TOKENS
## ----------------------------------------------------------------------------

## SANDBOX API URL & Token
sand_url   = "https://api.figsh.com/v2/" 
sand_token = AW_KEY_SAND

# 4TU API URL & Token
fig_url   = "https://api.figshare.com/v2/" 
fig_token = AW_KEY

# %%
## ----------------------------------------------------------------------------
# PREP - ADDITIONAL INFO - LICENCE AND CATEGORY IDs
# /licence and category IDs needed to update the metadata/
## ----------------------------------------------------------------------------

##-----------------------------------------------------------------------------
# LICENCES 
##-----------------------------------------------------------------------------

# SANDBOX 
response = requests.get(
    url = sand_url+"account/licenses", # public licences list
    #url = sand_url+"licenses", # private licences list
    headers = {
        "Authorization": f"token {sand_token}"
    })

sand_licences = response.json() # list of licences available together with thier IDs ( needed for metadata)
#sand_licences

# 4TU
response = requests.get(
    url = fig_url+"licenses" ,
    headers = {
        "Authorization": f"token {fig_token}"
    })

fig_licences = response.json() # list of licences available together with thier IDs ( needed for metadata)
#fig_licences

##-----------------------------------------------------------------------------
# CATEGORIES 
##-----------------------------------------------------------------------------

# SANDBOX
response = requests.get(
    url = sand_url+"account/categories",
    headers = {
        "Authorization": f"token {sand_token}"
    })

sand_cat = response.json()
#sand_cat

# 4TU
response = requests.get(
    url = fig_url+"account/categories",
    headers = {
        "Authorization": f"token {fig_token}"
    })

fig_cat = response.json()
sand_cat
# Out:
# [{'is_selectable': False,
#   'has_children': True,
#   'id': 5,
#   'title': 'Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 6,
#   'title': 'Physics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 8,
#   'title': 'Microbiology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 13,
#   'title': 'Genetics',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16,
#   'title': 'Physiology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18,
#   'title': 'Psychology',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 24,
#   'title': 'Evolutionary Biology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 25,
#   'title': 'Anthropology',
#   'parent_id': 26,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 27,
#   'title': 'Economics',
#   'parent_id': 26,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 29,
#   'title': 'Geology',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 32,
#   'title': 'Geochemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 36,
#   'title': 'Oceanography',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 37,
#   'title': 'Organic Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 38,
#   'title': 'Chemistry',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 39,
#   'title': 'Ecology',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 45,
#   'title': 'Sociology',
#   'parent_id': 26,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 46,
#   'title': 'Immunology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 48,
#   'title': 'Biological Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 52,
#   'title': 'Information And Computing Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 53,
#   'title': 'Mathematics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 69,
#   'title': 'Inorganic Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 78,
#   'title': 'Atmospheric Sciences',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 79,
#   'title': 'Geophysics',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 89,
#   'title': 'Aerospace Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 91,
#   'title': 'Mechanical Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 97,
#   'title': 'Law',
#   'parent_id': 50,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 100,
#   'title': 'Philosophy',
#   'parent_id': 50,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 105,
#   'title': 'Statistics',
#   'parent_id': 53,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 110,
#   'title': 'Condensed Matter Physics',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 127,
#   'title': 'Archaeology',
#   'parent_id': 26,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 129,
#   'title': 'Education',
#   'parent_id': 26,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 133,
#   'title': 'Plant Biology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 159,
#   'title': 'Zoology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 168,
#   'title': 'Linguistics',
#   'parent_id': 50,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 179,
#   'title': 'Artificial Intelligence and Image Processing',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 180,
#   'title': 'Computation Theory and Mathematics',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 181,
#   'title': 'Computer Software',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 182,
#   'title': 'Data Format',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 183,
#   'title': 'Distributed Computing',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 184,
#   'title': 'Information Systems',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 185,
#   'title': 'Library and Information Studies',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 245,
#   'title': 'Natural Hazards',
#   'parent_id': 33,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 994,
#   'title': 'Studies in Creative Arts and Writing',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1039,
#   'title': 'Technology',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1101,
#   'title': 'Built Environment and Design',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1138,
#   'title': 'Commerce, Management, Tourism and Services',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1180,
#   'title': 'Studies in Human Society',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 1213,
#   'title': 'International Relations',
#   'parent_id': 1180,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1221,
#   'title': 'Language, Communication and Culture',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1274,
#   'title': 'Agricultural and Veterinary Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 1801,
#   'title': 'Analytical Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 1807,
#   'title': 'Energy',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 1814,
#   'title': 'Theoretical and Computational Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 10493,
#   'title': 'Criminology',
#   'parent_id': 10490,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 10594,
#   'title': 'Marketing',
#   'parent_id': 10581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 10621,
#   'title': 'Cultural Studies',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 10664,
#   'title': 'Human Geography',
#   'parent_id': 10661,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 10671,
#   'title': 'Environmental Sciences',
#   'parent_id': 10661,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 15498,
#   'title': 'Manufacturing Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 15581,
#   'title': 'Health',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 15599,
#   'title': 'Dentistry',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 15749,
#   'title': 'Animal Production',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 15872,
#   'title': 'Econometrics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16177,
#   'title': 'Forestry',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16221,
#   'title': 'Chemical Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16241,
#   'title': 'Communication',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16286,
#   'title': 'Quantum Physics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 16301,
#   'title': 'Earth Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16371,
#   'title': 'Building',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 16680,
#   'title': 'Tourism',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 16932,
#   'title': 'Transport',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 17276,
#   'title': 'Microeconomics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 17403,
#   'title': 'Engineering Design',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 17721,
#   'title': 'Mineral Exploration',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 17797,
#   'title': 'Air Quality',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 17897,
#   'title': 'Horticultural Crops',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18055,
#   'title': 'Political Science',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 18311,
#   'title': 'Construction',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18330,
#   'title': 'Architecture',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18333,
#   'title': 'Biomedical Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18409,
#   'title': 'Applied Economics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18519,
#   'title': 'Environmental Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18639,
#   'title': 'Nanotechnology',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 18819,
#   'title': 'Demography',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 19060,
#   'title': 'Nursing',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 19345,
#   'title': 'International Trade',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 19417,
#   'title': 'Environmental Biotechnology',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 19567,
#   'title': 'Applied Mathematics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 19687,
#   'title': 'Macroeconomics',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 20104,
#   'title': 'Computer Hardware',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 20216,
#   'title': 'Civil Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 20264,
#   'title': 'Renewable Energy',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 20332,
#   'title': 'Manufacturing',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 20532,
#   'title': 'Neurosciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22835,
#   'title': 'Electrical and Electronic Engineering',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22872,
#   'title': 'Medical and Health Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22902,
#   'title': 'Design Practice and Management',
#   'parent_id': 1101,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22904,
#   'title': 'Urban and Regional Planning',
#   'parent_id': 1101,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22905,
#   'title': 'Other Built Environment and Design',
#   'parent_id': 1101,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22906,
#   'title': 'Law, Politics and Community Services',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22907,
#   'title': 'Community Service (excl. Work)',
#   'parent_id': 22906,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22908,
#   'title': 'Government and Politics',
#   'parent_id': 22906,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22910,
#   'title': 'Justice and The Law',
#   'parent_id': 22906,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22911,
#   'title': 'Work and Institutional Development',
#   'parent_id': 22906,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22912,
#   'title': 'Other Law, Politics and Community Services',
#   'parent_id': 22906,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22914,
#   'title': 'Agriculture, Land and Farm Management',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22916,
#   'title': 'Crop and Pasture Production',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22917,
#   'title': 'Fisheries Sciences',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22918,
#   'title': 'Forestry Sciences',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22919,
#   'title': 'Horticultural Production',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22920,
#   'title': 'Veterinary Sciences',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22921,
#   'title': 'Other Agricultural and Veterinary Sciences',
#   'parent_id': 1274,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22922,
#   'title': 'Environment',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22924,
#   'title': 'Atmosphere and Weather',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22925,
#   'title': 'Climate and Climate Change',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22926,
#   'title': 'Control of Pests, Diseases and Exotic Species',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22927,
#   'title': 'Ecosystem Assessment and Management',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22928,
#   'title': 'Environmental and Natural Resource Evaluation',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22929,
#   'title': 'Environmental Policy, Legislation and Standards',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22930,
#   'title': 'Flora, Fauna and Biodiversity',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22931,
#   'title': 'Land and Water Management',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22933,
#   'title': 'Physical and Chemical Conditions of Water',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22934,
#   'title': 'Rehabilitation of Degraded Environments',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22935,
#   'title': 'Remnant Vegetation and Protected Conservation Areas',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22936,
#   'title': 'Soils',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22937,
#   'title': 'Other Environment',
#   'parent_id': 22922,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22938,
#   'title': 'Plant Production and Plant Primary Products',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22941,
#   'title': 'Industrial Crops',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22942,
#   'title': 'Summer Grains and Oilseeds',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22943,
#   'title': 'Winter Grains and Oilseeds',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22944,
#   'title': 'Harvesting and Packing of Plant Products',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22945,
#   'title': 'Environmentally Sustainable Plant Production',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22946,
#   'title': 'Other Plant Production and Plant Primary Products',
#   'parent_id': 22938,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22948,
#   'title': 'Ecological Applications',
#   'parent_id': 10671,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22949,
#   'title': 'Environmental Science and Management',
#   'parent_id': 10671,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22950,
#   'title': 'Soil Sciences',
#   'parent_id': 10671,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22951,
#   'title': 'Other Environmental Sciences',
#   'parent_id': 10671,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22953,
#   'title': 'Clinical Health (organs, Diseases and Abnormal Conditions)',
#   'parent_id': 15581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22954,
#   'title': 'Health and Support Services',
#   'parent_id': 15581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22955,
#   'title': 'Public Health (excl. Specific Population Health)',
#   'parent_id': 15581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22956,
#   'title': 'Specific Population Health',
#   'parent_id': 15581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22957,
#   'title': 'Other Health',
#   'parent_id': 15581,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22958,
#   'title': 'Mineral Resources (excl. Energy Resources)',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22960,
#   'title': 'Primary Mining and Extraction of Mineral Resources',
#   'parent_id': 22958,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22961,
#   'title': 'First Stage Treatment of Ores and Minerals',
#   'parent_id': 22958,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22962,
#   'title': 'Environmentally Sustainable Mineral Resource Activities',
#   'parent_id': 22958,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22963,
#   'title': 'Other Mineral Resources (excl. Energy Resources)',
#   'parent_id': 22958,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22964,
#   'title': 'Law and Legal Studies',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22966,
#   'title': 'Maori Law',
#   'parent_id': 22964,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22967,
#   'title': 'Other Law and Legal Studies',
#   'parent_id': 22964,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22969,
#   'title': 'Pure Mathematics',
#   'parent_id': 53,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22971,
#   'title': 'Numerical and Computational Mathematics',
#   'parent_id': 53,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22973,
#   'title': 'Mathematical Physics',
#   'parent_id': 53,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22974,
#   'title': 'Other Mathematical Sciences',
#   'parent_id': 53,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22975,
#   'title': 'Animal Production and Animal Primary Products',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22976,
#   'title': 'Fisheries - Aquaculture',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22977,
#   'title': 'Fisheries - Wild Caught',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22978,
#   'title': 'Livestock Raising',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22979,
#   'title': 'Pasture, Browse and Fodder Crops',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22980,
#   'title': 'Primary Animal Products',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22981,
#   'title': 'Environmentally Sustainable Animal Production',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22982,
#   'title': 'Other Animal Production and Animal Primary Products',
#   'parent_id': 22975,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22983,
#   'title': 'History and Archaeology',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22985,
#   'title': 'Curatorial and Related Studies',
#   'parent_id': 22983,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22986,
#   'title': 'Historical Studies',
#   'parent_id': 22983,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22987,
#   'title': 'Other History and Archaeology',
#   'parent_id': 22983,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22988,
#   'title': 'Defence_',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22989,
#   'title': 'Defence',
#   'parent_id': 22988,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22990,
#   'title': 'Psychology and Cognitive Sciences',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22992,
#   'title': 'Cognitive Sciences',
#   'parent_id': 22990,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22993,
#   'title': 'Other Psychology and Cognitive Sciences',
#   'parent_id': 22990,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 22994,
#   'title': 'Commercial Services and Tourism',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22995,
#   'title': 'Financial Services',
#   'parent_id': 22994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22996,
#   'title': 'Property, Business Support Services and Trade',
#   'parent_id': 22994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22998,
#   'title': 'Water and Waste Services',
#   'parent_id': 22994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 22999,
#   'title': 'Environmentally Sustainable Commercial Services and Tourism',
#   'parent_id': 22994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23000,
#   'title': 'Other Commercial Services and Tourism',
#   'parent_id': 22994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23006,
#   'title': 'Policy and Administration',
#   'parent_id': 1180,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23008,
#   'title': 'Social Work',
#   'parent_id': 1180,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23010,
#   'title': 'Other Studies in Human Society',
#   'parent_id': 1180,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23012,
#   'title': 'Medical Biochemistry and Metabolomics',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23013,
#   'title': 'Cardiorespiratory Medicine and Haematology',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23014,
#   'title': 'Clinical Sciences',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23015,
#   'title': 'Complementary and Alternative Medicine',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23017,
#   'title': 'Human Movement and Sports Science',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23019,
#   'title': 'Medical Microbiology',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23022,
#   'title': 'Nutrition and Dietetics',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23023,
#   'title': 'Oncology and Carcinogenesis',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23024,
#   'title': 'Ophthalmology and Optometry',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23025,
#   'title': 'Paediatrics and Reproductive Medicine',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23026,
#   'title': 'Pharmacology and Pharmaceutical Sciences',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23027,
#   'title': 'Medical Physiology',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23028,
#   'title': 'Public Health and Health Services',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23029,
#   'title': 'Other Medical and Health Sciences',
#   'parent_id': 22872,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23030,
#   'title': 'Cultural Understanding',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23031,
#   'title': 'Arts and Leisure',
#   'parent_id': 23030,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23033,
#   'title': 'Heritage',
#   'parent_id': 23030,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23034,
#   'title': 'Religion and Ethics',
#   'parent_id': 23030,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23035,
#   'title': 'Understanding Past Societies',
#   'parent_id': 23030,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23036,
#   'title': 'Other Cultural Understanding',
#   'parent_id': 23030,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23038,
#   'title': 'Accounting, Auditing and Accountability',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23039,
#   'title': 'Banking, Finance and Investment',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23040,
#   'title': 'Business and Management',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23041,
#   'title': 'Commercial Services',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23043,
#   'title': 'Tourism - 4tu - 1',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23044,
#   'title': 'Transportation and Freight Services',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23045,
#   'title': 'Other Commerce, Management, Tourism and Services',
#   'parent_id': 1138,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23047,
#   'title': 'Construction Planning',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23048,
#   'title': 'Construction Design',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23049,
#   'title': 'Construction Materials Performance and Processes',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23050,
#   'title': 'Construction Processes',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23051,
#   'title': 'Building Management and Services',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23052,
#   'title': 'Environmentally Sustainable Construction',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23053,
#   'title': 'Other Construction',
#   'parent_id': 18311,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23055,
#   'title': 'Communication and Media Studies',
#   'parent_id': 1221,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23057,
#   'title': 'Language Studies',
#   'parent_id': 1221,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23059,
#   'title': 'Literary Studies',
#   'parent_id': 1221,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23060,
#   'title': 'Other Language, Communication and Culture',
#   'parent_id': 1221,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23062,
#   'title': 'Processed Food Products and Beverages (excl. Dairy Products)',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23063,
#   'title': 'Dairy Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23064,
#   'title': 'Processed Non-food Agriculture Products (excl. Wood, Paper and Fibre)',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23065,
#   'title': 'Leather Products, Fibre Processing and Textiles',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23066,
#   'title': 'Wood, Wood Products and Paper',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23067,
#   'title': 'Industrial Chemicals and Related Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23068,
#   'title': 'Agricultural Chemicals',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23069,
#   'title': 'Human Pharmaceutical Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23070,
#   'title': 'Veterinary Pharmaceutical Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23071,
#   'title': 'Ceramics, Glass and Industrial Mineral Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23072,
#   'title': 'Basic Metal Products (incl. Smelting, Rolling, Drawing and Extruding)',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23073,
#   'title': 'Fabricated Metal Products',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23074,
#   'title': 'Transport Equipment',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23075,
#   'title': 'Machinery and Equipment',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23076,
#   'title': 'Instrumentation',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23077,
#   'title': 'Computer Hardware and Electronic Equipment',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23078,
#   'title': 'Communication Equipment',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23079,
#   'title': 'Environmentally Sustainable Manufacturing',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23080,
#   'title': 'Other Manufacturing',
#   'parent_id': 20332,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23081,
#   'title': 'Information and Communication Services',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23082,
#   'title': 'Communication Networks and Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23083,
#   'title': 'Computer Software and Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23084,
#   'title': 'Information Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23085,
#   'title': 'Media Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23086,
#   'title': 'Environmentally Sustainable Information and Communication Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23087,
#   'title': 'Other Information and Communication Services',
#   'parent_id': 23081,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23094,
#   'title': 'Physical Geography and Environmental Geoscience',
#   'parent_id': 16301,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23095,
#   'title': 'Other Earth Sciences',
#   'parent_id': 16301,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23097,
#   'title': 'Art Theory and Criticism',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23098,
#   'title': 'Film, Television and Digital Media',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23099,
#   'title': 'Journalism and Professional Writing',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23100,
#   'title': 'Performing Arts and Creative Writing',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23101,
#   'title': 'Visual Arts and Crafts',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23102,
#   'title': 'Other Studies in Creative Arts and Writing',
#   'parent_id': 994,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23104,
#   'title': 'Economic Theory',
#   'parent_id': 27,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23107,
#   'title': 'Other Economics',
#   'parent_id': 27,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23108,
#   'title': 'Education and Training',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23109,
#   'title': 'Learner and Learning',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23110,
#   'title': 'Teaching and Instruction',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23111,
#   'title': 'Curriculum',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23112,
#   'title': 'School/institution',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23113,
#   'title': 'Education and Training Systems',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23114,
#   'title': 'Other Education and Training',
#   'parent_id': 23108,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23116,
#   'title': 'Biochemistry and Cell Biology',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23124,
#   'title': 'Other Biological Sciences',
#   'parent_id': 48,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23125,
#   'title': 'Philosophy and Religious Studies',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23126,
#   'title': 'Applied Ethics',
#   'parent_id': 23125,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23127,
#   'title': 'History and Philosophy of Specific Fields',
#   'parent_id': 23125,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23129,
#   'title': 'Religion and Religious Studies',
#   'parent_id': 23125,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23130,
#   'title': 'Other Philosophy and Religious Studies',
#   'parent_id': 23125,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23134,
#   'title': 'Macromolecular and Materials Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23135,
#   'title': 'Medicinal and Biomolecular Chemistry',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23137,
#   'title': 'Physical Chemistry (incl. Structural)',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23139,
#   'title': 'Other Chemical Sciences',
#   'parent_id': 38,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23141,
#   'title': 'Astronomical and Space Sciences',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23142,
#   'title': 'Atomic, Molecular, Nuclear, Particle and Plasma Physics',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23143,
#   'title': 'Classical Physics',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23145,
#   'title': 'Optical Physics',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23147,
#   'title': 'Other Physical Sciences',
#   'parent_id': 6,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23156,
#   'title': 'Other Information and Computing Sciences',
#   'parent_id': 52,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23158,
#   'title': 'Energy Exploration',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23159,
#   'title': 'Mining and Extraction of Energy Resources',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23160,
#   'title': 'Preparation and Production of Energy Sources',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23161,
#   'title': 'Energy Transformation',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23163,
#   'title': 'Energy Storage, Distribution and Supply',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23164,
#   'title': 'Energy Conservation and Efficiency',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23165,
#   'title': 'Environmentally Sustainable Energy Activities',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23166,
#   'title': 'Other Energy',
#   'parent_id': 1807,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23167,
#   'title': 'Expanding Knowledge_',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23168,
#   'title': 'Expanding Knowledge',
#   'parent_id': 23167,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23171,
#   'title': 'Automotive Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23177,
#   'title': 'Food Sciences',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23178,
#   'title': 'Geomatic Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23180,
#   'title': 'Maritime Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23181,
#   'title': 'Materials Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23183,
#   'title': 'Resources Engineering and Extractive Metallurgy',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23184,
#   'title': 'Interdisciplinary Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23185,
#   'title': 'Other Engineering',
#   'parent_id': 5,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23187,
#   'title': 'Education Systems',
#   'parent_id': 129,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23188,
#   'title': 'Curriculum and Pedagogy',
#   'parent_id': 129,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23189,
#   'title': 'Specialist Studies in Education',
#   'parent_id': 129,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23190,
#   'title': 'Other Education',
#   'parent_id': 129,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23192,
#   'title': 'Agricultural Biotechnology',
#   'parent_id': 1039,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23194,
#   'title': 'Industrial Biotechnology',
#   'parent_id': 1039,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23195,
#   'title': 'Medical Biotechnology',
#   'parent_id': 1039,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23196,
#   'title': 'Communications Technologies',
#   'parent_id': 1039,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23199,
#   'title': 'Other Technology',
#   'parent_id': 1039,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23201,
#   'title': 'Ground Transport',
#   'parent_id': 16932,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23202,
#   'title': 'Water Transport',
#   'parent_id': 16932,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23203,
#   'title': 'Aerospace Transport',
#   'parent_id': 16932,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23204,
#   'title': 'Environmentally Sustainable Transport',
#   'parent_id': 16932,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23205,
#   'title': 'Other Transport',
#   'parent_id': 16932,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': False,
#   'has_children': True,
#   'id': 23206,
#   'title': 'Economic Framework',
#   'parent_id': 0,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23210,
#   'title': 'Management and Productivity',
#   'parent_id': 23206,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23211,
#   'title': 'Measurement Standards and Calibration Services',
#   'parent_id': 23206,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058},
#  {'is_selectable': True,
#   'has_children': False,
#   'id': 23212,
#   'title': 'Other Economic Framework',
#   'parent_id': 23206,
#   'path': '',
#   'source_id': '',
#   'taxonomy_id': 1058}]

# %%
## ----------------------------------------------------------------------------
# CREATE ARTICLES 
## ----------------------------------------------------------------------------

# %%
## ----------------------------------------------------------------------------
# CREATE AN ARTICLE IN A 4TU
## ----------------------------------------------------------------------------

# Define metadata
art_title = 'GEF test 5'
art_license = 1
art_keywords = ['tag2', 'tag2', 'tag3']
art_description = 'description of my article'
#art_categories = ['Physical Geography and Environmental Geoscience', 'Geophysics']
#art_categories =  [ '79', '580' ] # Geophysics, Geodesy   
art_categories =  [ 13555, 13554 ] # Geophysics, Geodesy 
#art_categories = [{'id': 79}, {'id': 580} ]
art_custom_fields = {"Organizations": "TU Delft - Delft University of Technology;\nTU Delft, Faculty of Civil Engineering and Geosciences",
                 "Time coverage": "2022-01-01",
                 "Geolocation"  : "Cabauw Experimental Site for Atmospheric Research (CESAR): Meteo mast",
                 "Geolocation Longitude": "4.926",
                 "Geolocation Latitude" : "51.97",
                 "Format"       : "media types: application/x-netcdf"}


# Send the POST response to create the article 
response = requests.post(
    url    = f"{fig_url}/account/articles",
    data   = json.dumps({  "title": art_title, 
                           "description": art_description,
                           "license": art_license,
                           "tags": art_keywords,
                           "custom_fields": art_custom_fields
                           ,"categories": art_categories    # <- this doesn't work either with strings, IDs as strings or numerics; tried also categories_by_source_id, and add them as dictionary 
                        }),
    headers = {
        "Authorization": f"token {fig_token}",
        "Accept":       "application/json", 
        "Content-Type": "application/json" 
    })

# Get the article URL
article_url = None
if response.status_code == 201:
    article_url = response.headers["Location"] # Location header from the response referes to the url  (including article_id); Other interesting headers fields : Date
else:
    print ("Couldn't create article.")

# %%
## ----------------------------------------------------------------------------
# CREATE AN ARTICLE IN A SANDBOX ENVIRONMENT
## ----------------------------------------------------------------------------

# Define metadata
art_title = 'GEF test 6'
art_license = 50
#art_license = [{"value": 50}]
art_keywords = ['tag2', 'tag2', 'tag3']
art_description = 'description of my article' 
art_categories =  [ 79, 23094] # Geophysics, Physical Geography and Environmental Geoscience  
#art_categories_str =  [ '26834', '26840'] # Geophysics, Geodesy 
art_custom_fields = {"Organizations": "TU Delft - Delft University of Technology;\nTU Delft, Faculty of Civil Engineering and Geosciences",
                 "Time coverage": "2022-01-01",
                 "Geolocation"  : "Cabauw Experimental Site for Atmospheric Research (CESAR): Meteo mast",
                 "Geolocation Longitude": "4.926",
                 "Geolocation Latitude" : "51.97",
                 "Format"       : "media types: application/x-netcdf"}
art_authors =  [
    {
      "name": 'Trinity'
    },
    {
      "name": 'Neo'
    },
    {
      "name": "John Doe"
    }
  ]


# Send the POST response to create the article 
response = requests.post(
    url    = f"{sand_url}/account/articles",
    data   = json.dumps({  "title": art_title, 
                           # "license": art_license, <- this notation results in a 404 response
                           "licence": art_license, # <- this notation results in 201 response, but licence is not altered on the website
                           "tags": art_keywords,
                           "description": art_description, 
                           "custom_fields": art_custom_fields
                           ,"categories": art_categories # <- this notation results in a 404 ( not found) response
                            #,"categories": art_categories_str # <- this notation results in a 400 (bad request) response 
                           ,"authors": art_authors
                        }),
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json", 
        "Content-Type": "application/json" 
    })

# Get the article URL
article_url = None
if response.status_code == 201:
    article_url = response.headers["Location"] # Location header from the response referes to the url  (including article_id); Other interesting headers fields : Date
else:
    print ("Couldn't create article.")

# %%
# Try to update licence as a separate step <- STILL NOTHING
response = requests.put(
    url = article_url,
    data   = json.dumps({  "licence": art_license}),
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json", 
        "Content-Type": "application/json" 
    }
)

# %%
# Manually add the licence and check the api response body
response = requests.get(
    url = article_url,
    headers = {"Authorization": f"token {sand_token}"}
)

article_data = response.json()
license_id      = article_data["license"]
license_id
# Out:
# {'value': None, 'name': None, 'url': None}

# %%
## -----------------------------------------------------------------------------
# Reserve DOI
## -----------------------------------------------------------------------------

response = requests.post(
    url = f"{article_url}/reserve_doi",
    headers = {"Authorization": f"token {sand_token}"}
)

# response.status_code

# %%
##-----------------------------------------------------------------------------
# UPLOAD DATASET
##-----------------------------------------------------------------------------

# Define data path 
file_path = 'LBBR_28-1.GEF'


## INITIATE UPLOAD / REGISTER A FILE
file_size    = os.path.getsize(file_path) # checks size of file
md5          = hashlib.md5() # define checksum method

computed_md5 = None
with open (file_path, "rb") as stream: 
    for chunk in iter(lambda: stream.read(4096), b""):
        md5.update(chunk)
        computed_md5 = md5.hexdigest() 

response     = requests.post(
    url     = f"{article_url}/files", 
    data    = json.dumps({
        "name": "LBR_28-1",
        "md5":  computed_md5,
        "size": file_size
    }),
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json",
        "Content-Type": "application/json"
    })

file_url = None
if response.status_code == 201:
    file_url = response.headers["Location"]
else:
    print ("Couldn't create file.")

## GET UPLOAD METADATA

response = requests.get(
    url   = file_url,
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json",
    })

file_data = response.json()
file_id      = file_data["id"]
upload_token = file_data["upload_token"]
upload_url   = file_data["upload_url"]

response = requests.get(
    url = upload_url,
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json",
    })

#response.status_code

upload_metadata = response.json()

# UPLOAD PARTS

parts_metadata = upload_metadata["parts"]
file_stream    = open(file_path, "rb")

for part in parts_metadata:
    part_number     = part["partNo"]
    start_position  = part['startOffset']
    end_position    = part['endOffset']
    number_of_bytes = end_position - start_position + 1
    print(f"Uploading part {part_number} ({number_of_bytes} bytes).")
    file_stream.seek(start_position)
    chunk    = file_stream.read(number_of_bytes)
    response = requests.put(
        url = f"{upload_url}/{part_number}",
        headers = {
            "Authorization": f"token {sand_token}",
            "Accept":       "application/json",
        },
        data = chunk)

file_stream.close()


# CHECK NEW FILE STATUS

response = requests.get(
    url = upload_url,
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json",
    })

response.status_code
upload_metadata = response.json()
upload_metadata

# FINALIZE UPLOAD

response = requests.post(
    url     = f"{article_url}/files/{file_id}",
    headers = {
        "Authorization": f"token {sand_token}",
        "Accept":       "application/json",
    })

# response.status_code
# Out:
# Uploading part 1 (1697 bytes).

# %%
##------------------------------------------
# PUBLISH ARTICLE
##------------------------------------------

##### NOTE #####################################
#
# When an article is published, a new public version will be generated.
# Any further updates to the article will affect the private article data.
# In order to make these changes publicly visible, an explicit publish operation is needed.
#
###############################################

response = requests.post(
    url = f"{article_url}/publish",
    headers = {"Authorization": f"token {sand_token}"}
)

# %%
##------------------------------------------
# ADD THE ARTICLE TO A  COLLECTION         <- Adapt private version ; publish - collecion iD stays the same, but the upload will create a new version
##------------------------------------------

# Input for the collection update
collection_id = 2977400 # <-test  collection in sandbox
article_id = [int(re.search('/([0-9]+)$', article_url).group(1))] # retrieve article id from URL
api_url = f"{sand_url}account/collections/{collection_id}/" # url to add article to a private collection


# ADD THE ARTICLE TO A PRIVATE COLLECTION
response = requests.post(
    url = f"{api_url}articles",
    data   = json.dumps({  "articles": article_id}),
    headers = {"Authorization": f"token {sand_token}",
               "Accept":       "application/json",
               "Content-Type": "application/json"}
)

# print('ADD article: ', response.status_code)
    
# PUBLISH THE COLLECTION 
response = requests.post(
    url = f"{api_url}publish",
    headers = {"Authorization": f"token {sand_token}"}
)

# print("Publish collection: ", response.status_code)
    
#response.status_code
# Out:
# ADD article:  201
# Publish collection:  201

# %%
# ToDO 
# 1.  Figure out licence (only in sandbox, it does work in the 4TU)
# 5.  Start compiling an input pipeline
# Out:
# 201

# %%
# SANDBOX 
response = requests.get(
    url = sand_url+"account/licenses", # public licences list
    #url = sand_url+"licenses", # private licences list
    headers = {
        "Authorization": f"token {sand_token}"
    })

sand_licences = response.json() # list of licences available together with thier IDs ( needed for metadata)
sand_licences
# Out:
# [{'value': 2,
#   'name': 'CC-0',
#   'url': 'https://creativecommons.org/publicdomain/zero/1.0/'},
#  {'value': 50,
#   'name': 'CC BY 4.0',
#   'url': 'https://creativecommons.org/licenses/by/4.0/'},
#  {'value': 58,
#   'name': 'CC BY-SA 4.0',
#   'url': 'https://creativecommons.org/licenses/by-sa/4.0/'},
#  {'value': 54,
#   'name': 'CC BY-ND 4.0',
#   'url': 'https://creativecommons.org/licenses/by-nd/4.0/'},
#  {'value': 52,
#   'name': 'CC BY-NC 4.0',
#   'url': 'https://creativecommons.org/licenses/by-nc/4.0/'},
#  {'value': 59,
#   'name': 'CC BY-NC-SA 3.0',
#   'url': 'https://creativecommons.org/licenses/by-nc-sa/3.0/'},
#  {'value': 60,
#   'name': 'CC BY-NC-SA 4.0',
#   'url': 'https://creativecommons.org/licenses/by-nc-sa/4.0/'},
#  {'value': 56,
#   'name': 'CC BY-NC-ND 4.0',
#   'url': 'https://creativecommons.org/licenses/by-nc-nd/4.0/'},
#  {'value': 142,
#   'name': 'Restrictive Licence',
#   'url': 'https://data.4tu.nl/info/fileadmin/user_upload/Documenten/4TU.ResearchData_Restricted_Data_2022.pdf'},
#  {'value': 3, 'name': 'MIT', 'url': 'https://opensource.org/licenses/MIT'},
#  {'value': 140,
#   'name': 'BSD-3-Clause',
#   'url': 'https://opensource.org/licenses/BSD-3-Clause'},
#  {'value': 7,
#   'name': 'Apache-2.0',
#   'url': 'https://www.apache.org/licenses/LICENSE-2.0.html'},
#  {'value': 87,
#   'name': 'EUPL-1.2',
#   'url': 'https://opensource.org/licenses/EUPL-1.2'},
#  {'value': 5,
#   'name': 'GPL-2.0',
#   'url': 'https://www.gnu.org/licenses/gpl-2.0.html'},
#  {'value': 6,
#   'name': 'GPL-3.0',
#   'url': 'https://www.gnu.org/licenses/gpl-3.0.html'},
#  {'value': 80,
#   'name': 'LGPL-3.0',
#   'url': 'https://opensource.org/licenses/lgpl-3.0.html'},
#  {'value': 122,
#   'name': 'AGPL-3.0',
#   'url': 'https://www.gnu.org/licenses/agpl-3.0.en.html'},
#  {'value': 85,
#   'name': '4TU General Terms of Use',
#   'url': 'https://doi.org/10.4121/resource:terms_of_use'}]
